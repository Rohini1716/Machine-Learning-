# %% [markdown]
#   # **📌 Project Title**

# %% [markdown]
# *🚘 "Price Prediction & Market Trends of Used Cars in Bangladesh"*

# %% [markdown]
# # **🚗 Introduction**

# %% [markdown]
# The dataset contains detailed information about used cars listed in Bangladesh, providing insights into the country’s second-hand automobile market. It consists of 1,500 records and 12 attributes, covering key features such as car brand and model, year of manufacture, mileage, engine capacity, ownership history, location, and both new and resale prices.
#
# This dataset is valuable for:
#
# Market Analysis → Understanding pricing trends and demand in different cities.
#
# Predictive Modeling → Building machine learning models to predict resale car prices.
#
# Consumer Insights → Identifying how factors like fuel type, transmission, mileage, and ownership influence resale value.
#
# Business Applications → Assisting car dealers, buyers, and sellers in making data-driven decisions.

# %% [markdown]
#  # **📊 Dataset-Information**

# %% [markdown]
# The dataset is collected from the Kaggle website.

# %% [markdown]
#   **🔍 Key Columns in the Dataset**

# %% [markdown]
# Columns & Description
#
# name → Car brand and model (e.g., Hyundai Accent, Suzuki Alto)
#
# location → City where car is listed (e.g., Dhaka, Rajshahi, Chittagong)
#
# year → Year of manufacture
#
# kilometers_driven → Total distance driven by the car
#
# fuel_type → Type of fuel (Diesel, Petrol, CNG, Hybrid, etc.)
#
# transmission → Gear type (Manual, Automatic)
#
# owner → Ownership history (First, Second, Third, Fourth & Above)
#
# mileage → Mileage of car (e.g., “24.01 kmpl”)
#
# engine → Engine capacity (e.g., “2278 CC”)
#
# seats → Number of seats (e.g., 4, 5, 7)
#
# new_price → Price of the car when new (in Lakhs)
#
# price → Resale price (used car market price)

# %% [markdown]
#  # **🧩 Imports Libraries**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  # **📥 Loading the Dataset**

# %%
data=pd.read_csv("bangladesh_used_car_data_with_nan.csv")
df=data.copy()

# %% [markdown]
#  # **👀 Viewing the Data**

# %%
data.head(5)
# Out:
#              name    location  year  kilometers_driven fuel_type transmission  \
# 0  Hyundai Accent    Rajshahi  2007             190494    Diesel    Automatic
# 1     Suzuki Alto  Chittagong  2017             153464    Hybrid       Manual
# 2    Nissan Sunny    Rajshahi  2013              54724    Hybrid       Manual
# 3     Suzuki Alto      Khulna  2010              42299    Hybrid       Manual
# 4     Suzuki Alto       Dhaka  2016              25641       CNG    Automatic
#
#             owner     mileage   engine  seats   new_price  price
# 0          Second  24.01 kmpl  2278 CC    7.0  24.38 Lakh  11.87
# 1          Second  18.04 kmpl   825 CC    7.0   10.8 Lakh  24.26
# 2  Fourth & Above  11.53 kmpl  2313 CC    4.0  30.57 Lakh  18.65
# 3           Third  24.65 kmpl  1831 CC    4.0  29.99 Lakh  11.47
# 4  Fourth & Above  22.34 kmpl  1768 CC    5.0  22.41 Lakh   2.44

# %%
data.tail(5)
# Out:
#                 name    location  year  kilometers_driven fuel_type  \
# 1495  Hyundai Accent    Rajshahi  2007              72894    Petrol
# 1496     Suzuki Alto      Sylhet  2009             175707    Petrol
# 1497     Suzuki Alto      Khulna  2007              17465    Hybrid
# 1498  Hyundai Accent  Chittagong  2020              66754    Petrol
# 1499  Hyundai Accent    Rajshahi  2021             102850    Diesel
#
#      transmission   owner     mileage   engine  seats   new_price  price
# 1495       Manual   First  17.13 kmpl  2326 CC    4.0  25.92 Lakh  20.25
# 1496       Manual  Second  13.26 kmpl  1755 CC    7.0  12.09 Lakh   2.79
# 1497    Automatic   Third  19.78 kmpl  2053 CC    7.0  10.79 Lakh  24.60
# 1498       Manual   Third  25.88 kmpl  1930 CC    4.0  23.47 Lakh  21.90
# 1499       Manual   First  23.23 kmpl  2212 CC    5.0  18.84 Lakh  15.33

# %% [markdown]
#  # **🛠️ Apply Functions**

# %% [markdown]
# 1.Columns and Rows

# %%
data.shape
# Out:
# (1500, 12)

# %% [markdown]
# 2.Data Types

# %%
data.dtypes
# Out:
# name                  object
# location              object
# year                   int64
# kilometers_driven      int64
# fuel_type             object
# transmission          object
# owner                 object
# mileage               object
# engine                object
# seats                float64
# new_price             object
# price                float64
# dtype: object

# %% [markdown]
# 3.Dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1500 non-null   object
#  1   location           1500 non-null   object
#  2   year               1500 non-null   int64
#  3   kilometers_driven  1500 non-null   int64
#  4   fuel_type          1500 non-null   object
#  5   transmission       1500 non-null   object
#  6   owner              1500 non-null   object
#  7   mileage            1425 non-null   object
#  8   engine             1425 non-null   object
#  9   seats              1425 non-null   float64
#  10  new_price          1500 non-null   object
#  11  price              1500 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 140.8+ KB

# %% [markdown]
# **🧮 Statistical Analysis**

# %%
data.describe()
# Out:
#              year  kilometers_driven        seats        price
# count  1500.00000        1500.000000  1425.000000  1500.000000
# mean   2013.69600      104142.999333     5.334737    13.556833
# std       5.19977       54039.919905     1.238240     6.542680
# min    2005.00000       10066.000000     4.000000     2.000000
# 25%    2009.00000       57940.750000     4.000000     7.965000
# 50%    2014.00000      104735.500000     5.000000    13.745000
# 75%    2018.00000      150975.750000     7.000000    19.080000
# max    2022.00000      199933.000000     7.000000    24.990000

# %% [markdown]
# # **🧹 Cleaning Data**

# %% [markdown]
# **1)Find Null Values**

# %%
data.isnull().sum()
# Out:
# name                  0
# location              0
# year                  0
# kilometers_driven     0
# fuel_type             0
# transmission          0
# owner                 0
# mileage              75
# engine               75
# seats                75
# new_price             0
# price                 0
# dtype: int64

# %% [markdown]
# **2)Fill Null Values**

# %%
data['mileage'].fillna(data['mileage'].mode()[0],inplace=True)

# %%
data['engine'].fillna(data['engine'].mode()[0],inplace=True)

# %%
data['seats'].fillna(data['seats'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# name                 0
# location             0
# year                 0
# kilometers_driven    0
# fuel_type            0
# transmission         0
# owner                0
# mileage              0
# engine               0
# seats                0
# new_price            0
# price                0
# dtype: int64

# %% [markdown]
# **3) Change the Data Types**

# %%
data['seats']=data['seats'].astype('int')

# %%
data['mileage'] = data['mileage'].str.extract('(\d+\.?\d*)').astype(float)

# %%
data['engine'] = data['engine'].str.extract('(\d+)').astype(float)

# %%
data.dtypes
# Out:
# name                  object
# location              object
# year                   int64
# kilometers_driven      int64
# fuel_type             object
# transmission          object
# owner                 object
# mileage              float64
# engine               float64
# seats                  int64
# new_price             object
# price                float64
# dtype: object

# %% [markdown]
#  **4)Find the Outliers**

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %% [markdown]
#  **5)🔢Label Encoding of Categorical Features**

# %%
from sklearn.preprocessing import LabelEncoder
columns=['owner','transmission','fuel_type','name']
le=LabelEncoder()
for col in columns:
    data['encoded_',col]=le.fit_transform(data[col])

# %%
data
# Out:
#                 name    location  year  kilometers_driven fuel_type  \
# 0     Hyundai Accent    Rajshahi  2007             190494    Diesel
# 1        Suzuki Alto  Chittagong  2017             153464    Hybrid
# 2       Nissan Sunny    Rajshahi  2013              54724    Hybrid
# 3        Suzuki Alto      Khulna  2010              42299    Hybrid
# 4        Suzuki Alto       Dhaka  2016              25641       CNG
# ...              ...         ...   ...                ...       ...
# 1495  Hyundai Accent    Rajshahi  2007              72894    Petrol
# 1496     Suzuki Alto      Sylhet  2009             175707    Petrol
# 1497     Suzuki Alto      Khulna  2007              17465    Hybrid
# 1498  Hyundai Accent  Chittagong  2020              66754    Petrol
# 1499  Hyundai Accent    Rajshahi  2021             102850    Diesel
#
#      transmission           owner  mileage  engine  seats   new_price  price  \
# ...

# %% [markdown]
# **6)Dropping Irrelevant Features**

# %%
data.drop(columns=['name','new_price','location','fuel_type','transmission','owner'],axis=1,inplace=True)

# %%
data
# Out:
#       year  kilometers_driven  mileage  engine  seats  price  \
# 0     2007             190494    24.01  2278.0      7  11.87
# 1     2017             153464    18.04   825.0      7  24.26
# 2     2013              54724    11.53  2313.0      4  18.65
# 3     2010              42299    24.65  1831.0      4  11.47
# 4     2016              25641    22.34  1768.0      5   2.44
# ...    ...                ...      ...     ...    ...    ...
# 1495  2007              72894    17.13  2326.0      4  20.25
# 1496  2009             175707    13.26  1755.0      7   2.79
# 1497  2007              17465    19.78  2053.0      7  24.60
# 1498  2020              66754    25.88  1930.0      4  21.90
# 1499  2021             102850    23.23  2212.0      5  15.33
#
#       (encoded_, owner)  (encoded_, transmission)  (encoded_, fuel_type)  \
# 0                     2                         0                      1
# 1                     2                         1                      2
# ...

# %% [markdown]
#  # **🖼️ Data Visualization**

# %% [markdown]
# # *👉Histogram*

# %%
numeric_cols = data.select_dtypes(include='number').columns
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    plt.hist(data[col].dropna(), bins=30, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %% [markdown]
#  # *👉Boxplot*

# %%
numeric_cols = data.select_dtypes(include='number').columns
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    plt.boxplot(data[col].dropna(), vert=True, patch_artist=True)
    plt.title(f"Boxplot of {col}")
    plt.ylabel(col)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %% [markdown]
#  # *👉Heatmap*

# %%
numeric_data = data.select_dtypes(include='number')
corr = numeric_data.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(corr, annot=True, cmap="Blues", fmt=".2f", linewidths=0.5, cbar=True)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# # **📉 Linear Regression**

# %%
y=data['price']
x=data.drop(['price'],axis=1)

# %%
x.columns = x.columns.map(str)

# %%
from sklearn.model_selection import train_test_split
x_test, x_train, y_test, y_train=train_test_split(x,y,train_size=0.8, random_state=42)
x_train.shape,x_test.shape,y_test.shape,y_train.shape
# Out:
# ((300, 9), (1200, 9), (1200,), (300,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([11.23120978, 13.84864738, 12.57447277, ..., 12.52669319,
#        12.6349568 , 13.18839282], shape=(1200,))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error, r2_score

# %%
print("Linear Regression Model Results")
print("Mean_squared_error value:", mean_squared_error(y_test,y_pred))
print("Mean_Absolute_percentage error value:", mean_absolute_percentage_error(y_test,y_pred))
print("Mean_Absolute_error value:", mean_absolute_error(y_test,y_pred))
print("R² Score value:", r2_score(y_test,y_pred))
# Out:
# Linear Regression Model Results
# Mean_squared_error value: 47.43432634759308
# Mean_Absolute_percentage error value: 0.67324854672228
# Mean_Absolute_error value: 5.917256502069936
# R² Score value: -0.08959814868888416

# %% [markdown]
# # **🌳 Decision Tree Regression**

# %%
y=data['price']
x=data.drop(['price'],axis=1)

# %%
x.columns = x.columns.map(str)

# %%
x_test, x_train, y_test, y_train=train_test_split(x,y,train_size=0.8, random_state=42)
x_train.shape,x_test.shape,y_test.shape,y_train.shape
# Out:
# ((300, 9), (1200, 9), (1200,), (300,))

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(max_depth=10, random_state=42) 
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, random_state=42)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 7.55636364,  9.72      ,  5.07      , ..., 10.88166667,
#        20.54      , 19.97      ], shape=(1200,))

# %%
print("Decision Tree Model Results")
print("Mean_squared_error value:", mean_squared_error(y_test,y_pred))
print("Mean_Absolute_percentage error value:", mean_absolute_percentage_error(y_test,y_pred))
print("Mean_Absolute_error value:", mean_absolute_error(y_test,y_pred))
print("R² Score value:", r2_score(y_test,y_pred))
# Out:
# Decision Tree Model Results
# Mean_squared_error value: 82.61383173005169
# Mean_Absolute_percentage error value: 0.7801783995681494
# Mean_Absolute_error value: 7.411561316378066
# R² Score value: -0.8976948771135427

# %% [markdown]
# # **🤖📈Support Vector Regression**

# %%
y=data['price']
x=data.drop(['price'],axis=1)

# %%
x.columns = x.columns.map(str)

# %%
from sklearn.preprocessing import StandardScaler
num_cols = data.select_dtypes(include=np.number)
num_cols.columns = num_cols.columns.astype(str)
std_scaler = StandardScaler()
scaled_data = std_scaler.fit_transform(num_cols)
print("Standard Scaler")
print(scaled_data)
# Out:
# Standard Scaler
# [[-1.28817871  1.59844424  0.70686794 ... -0.99203175 -0.46926122
#   -0.73549882]
#  [ 0.63562462  0.91298154 -0.27539278 ...  1.00803226  0.43548406
#    0.67080867]
#  [-0.13389671 -0.91479559 -1.3465012  ...  1.00803226  0.43548406
#   -0.03234507]
#  ...
#  [-1.28817871 -1.60449732  0.01089426 ... -0.99203175  0.43548406
#    0.67080867]
#  [ 1.21276562 -0.69210814  1.01454425 ...  1.00803226  1.34022933
#   -0.73549882]
#  [ 1.40514595 -0.02393472  0.57853237 ...  1.00803226 -0.46926122
#   -0.73549882]]

# %%
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
x_train.shape,x_test.shape,y_test.shape,y_train.shape
# Out:
# ((1200, 9), (300, 9), (300,), (1200,))

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel='rbf')
svr_model.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred= svr_model.predict(x_test)
y_pred
# Out:
# array([14.39367493, 14.28355766, 14.3960871 , 14.43602931, 14.1836007 ,
#        14.07333164, 14.61886136, 13.98914618, 14.71610703, 14.11485579,
#        14.72536838, 14.35886029, 13.77487394, 14.23333981, 14.72624663,
#        14.37196801, 14.45899779, 14.00481806, 14.71013888, 14.64143348,
#        13.7270948 , 14.57933481, 14.18800981, 14.50429655, 14.3413358 ,
#        14.58384013, 14.30813281, 14.01541997, 14.33135447, 14.12525323,
#        14.58525655, 14.60616996, 13.99076791, 14.13721853, 14.66769995,
#        13.98792349, 14.34326903, 14.15088492, 14.63167641, 14.65476839,
#        14.58440283, 14.71248169, 14.45774189, 14.12657441, 14.01421621,
#        13.99396821, 14.70122199, 14.2044402 , 14.59540445, 14.62695629,
#        14.62694104, 14.46841629, 14.08208933, 14.2627014 , 13.99057728,
#        14.70617742, 14.00496504, 14.51073331, 13.87342377, 14.0492347 ,
#        14.09255414, 13.98690103, 14.00370157, 14.55757546, 14.13337646,
# ...

# %%
print("Support Vector  Regression Model Results")
print("Mean_squared_error value:", mean_squared_error(y_test,y_pred))
print("Mean_Absolute_percentage error value:", mean_absolute_percentage_error(y_test,y_pred))
print("Mean_Absolute_error value:", mean_absolute_error(y_test,y_pred))
print("R² Score value:", r2_score(y_test,y_pred))
# Out:
# Support Vector  Regression Model Results
# Mean_squared_error value: 41.89789651420029
# Mean_Absolute_percentage error value: 0.817835931068768
# Mean_Absolute_error value: 5.594141681263487
# R² Score value: -0.10401738368772384

# %% [markdown]
#  # **💾 Saving Model**

# %%
import pickle
with open('model.pkl','wb') as file:
    pickle.dump(SVR,file)

# %% [markdown]
#  # **🚗 Used Car Dataset – Complete Analysis**

# %% [markdown]
# **📌  Introduction**
#
# The dataset contains information about used cars in Bangladesh, including price, brand, model, year, mileage, engine, fuel type, and other features. The main goal is to analyze car characteristics and build predictive models to estimate car prices.

# %% [markdown]
# **🔹.  Dataset Information**(use shape function)

# %% [markdown]
# Rows: 1500
#
# Columns: 12 (price, year, name, model, mileage, engine, fuel_type, transmission, kilometers_driven)

# %% [markdown]
# **🔹Mean and Median Values**(use describe function)

# %% [markdown]
# Statistical analysis is the process of examining data using mathematical techniques to summarize, describe, and interpret patterns, trends, and relationships. It includes measures like mean, median, mode, variance, standard deviation, and correlation to gain insights from data.

# %% [markdown]
# | Feature               | Mean         | Median     |
# | --------------------- | ------------ | ---------- |
# | **Price**             | 1,035,952.25 | 997,667.00 |
# | **Year**              | 2009.68      | 2008.50    |
# | **Kilometers Driven** | 103,323.50   | 107,208.00 |
# | **Mileage**           | 17.91        | 18.54      |
# | **Engine**            | 1877.11      | 1873.50    |

# %% [markdown]
# **🔹Changing the Datatype**

# %% [markdown]
# Data type change refers to converting a column’s values from one type to another (e.g., from string to integer or float) to ensure proper analysis or model compatibility.

# %% [markdown]
# ->Seats-Float to int (use astype function)

# %% [markdown]
# ->Mileage - Remove (Kmpl) (use extract fuction)

# %% [markdown]
# ->Engine - Remove (CC) (use extract function)

# %% [markdown]
# **🔹Missing Values**(use isnull() function)

# %% [markdown]
# Missing values are gaps or absent entries in a dataset where no data is recorded for a particular feature. They can be handled by techniques like removing rows/columns, imputing with mean/median/mode, or using algorithms that support missing data.

# %% [markdown]
# Seats = 75 missing values

# %% [markdown]
# mileage = 75 missing values

# %% [markdown]
# Engine = 75 missing values

# %% [markdown]
# **🔹Label Encoding**

# %% [markdown]
# Label Encoder is a preprocessing tool in machine learning that converts categorical text data into numeric form, assigning each unique category an integer. It is commonly used for transforming target labels or categorical features for algorithms that require numerical input.

# %% [markdown]
# name, owner, fuel_type, transmission

# %% [markdown]
# **🔹Drop columns**

# %% [markdown]
# Dropping columns is a data preprocessing step where unnecessary or irrelevant columns are removed from a dataset to simplify analysis or improve model performance.

# %% [markdown]
# name, location, new price, transmission, fuel type, owner.

# %% [markdown]
# **🔹Histogram**

# %% [markdown]
# Most cars are from recent years (2015–2021), and kilometers driven are spread across different ranges.
#
# Mileage and engine sizes vary, but many cars fall in lower mileage (around 12–14 kmpl) and smaller engine ranges.
#
# Seat counts are concentrated mostly at 5, with some at 4 and 7.
#
# Prices are fairly spread out, mostly between 5–20 lakhs.
#
# Encoded categorical features (owner, fuel type, transmission, name) show balanced distributions across their categories.

# %% [markdown]
# **🔹Boxplot**

# %% [markdown]
# Most cars are from around 2010–2020, with a few older and newer ones.
#
# Kilometers driven mostly range between 50,000–150,000, but some cars have very low or very high usage.
#
# Mileage usually lies between 15–25 kmpl, while engine sizes are mostly 1200–1800 cc.
#
# Seats are mostly 4, 5, or 7, while car prices fall mostly between 10–20 lakhs.
#
# Encoded categorical features (owner, transmission, fuel type, name) are spread across their categories without extreme outliers.

# %% [markdown]
# **🔹Heatmap**

# %% [markdown]
# Most features show very weak or no correlation with each other.
#
# Price has almost no strong relationship with engine, mileage, or year.
#
# Seats have a slightly negative correlation with price, but it’s still very weak.
#
# Encoded categorical variables (owner, transmission, fuel type, name) also show minimal correlation with numerical features.
#
# Overall, the dataset does not have multicollinearity issues, as correlations are close to zero.

# %% [markdown]
# **🔹Linear Regression**

# %% [markdown]
# we use

# %% [markdown]
# 80% for Training-20% for Testing

# %% [markdown]
# MSE - 47.43432634759308

# %% [markdown]
# MAE - 5.917256502069936

# %% [markdown]
# MAPE - 0.67324854672228

# %% [markdown]
# R2 square Error - -0.08959814868888416

# %% [markdown]
# **🔹Decisison Tree Regression**

# %% [markdown]
# we use

# %% [markdown]
# 80% for Training - 20% for Testing

# %% [markdown]
# MSE - 82.61383173005169.

# %% [markdown]
# MAE - 7.411561316378066

# %% [markdown]
# MAPE - 0.7801783995681494

# %% [markdown]
# R2 Square Error - -0.8976948771135427

# %% [markdown]
# **🔹Support Vector Regression**

# %% [markdown]
# we use

# %% [markdown]
# 80% for Training - 20% for Testing

# %% [markdown]
# MSE - 41.89789651420029

# %% [markdown]
# MAE - 5.594141681263487

# %% [markdown]
# MAPE - 0.817835931068768

# %% [markdown]
# R2 Square Error -  -0.10401738368772384

# %% [markdown]
#  # **🧾 Conclusion**

# %% [markdown]
# The project analyzed the used car market in Bangladesh using data of 1,500 vehicles with multiple attributes.
#
# Important factors like brand, year, mileage, engine capacity, fuel type, and ownership strongly influenced resale prices.
#
# Data cleaning, visualization, and statistical analysis helped uncover trends and outliers.
#
# Machine learning models were applied to predict car resale prices with good accuracy.
#
# Overall, the study provides valuable insights for buyers, sellers, and dealers to make data-driven decisions in the second-hand car market.
